# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience


import pims
import trackpy as tp
import av

from scipy.optimize import curve_fit

import time

# %% [markdown]
# # Import video

# %%
frames = pims.as_grey(pims.PyAVReaderTimed("videos/1.5g@30Hz_long.mp4"))
